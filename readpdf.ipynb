# %% [markdown]
# # ANALYSIS OF REGISTERED PUBLICATIONS

# %%
import tabula as tb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = tb.read_pdf("C:\\Users\\XX\\Documents\\Chapter 2.pdf",pages=7)

# %%
#df[0] = df[0].rename(columns=df[0].iloc[0]).drop(df[0].index[0])

# %%
regpublication_df = df[0]

# %%
regpublication_df
# Out:
#     S. No      Language  Daily  Bi/Tri-\rWeekly  Weekly  Fortnightly  Monthly  \
# 0     1.0      Assamese     58               11     130           55      137
# 1     2.0       Bengali    233               29    1027         1044     1498
# 2     3.0          Bodo      4                1       4            1        5
# 3     4.0         Dogri      1                0       3            0        1
# 4     5.0      Gujarati    811               15    2906          784     1880
# 5     6.0         Hindi   8562              141   22768         6628    14265
# 6     7.0       Kannada   1117                9    1092         1043     2490
# 7     8.0      Kashmiri      3                0       4            0        2
# 8     9.0       Konkani      4                0      16            3       39
# 9    10.0      Maithili      6                0       2            3       13
# 10   11.0     Malayalam    435               18     387          340     2018
# ...

# %%
regpublication_df.dtypes
# Out:
# S. No              float64
# Language            object
# Daily                int64
# Bi/Tri-\rWeekly      int64
# Weekly               int64
# Fortnightly          int64
# Monthly              int64
# Quarterly            int64
# Annual               int64
# Others               int64
# Total                int64
# dtype: object

# %%
regpublication_df = regpublication_df.drop(["S. No","Total"],axis=1)

# %%
regpublication_df = regpublication_df[regpublication_df.Language != 'Total']
regpublication_df
# Out:
#         Language  Daily  Bi/Tri-\rWeekly  Weekly  Fortnightly  Monthly  \
# 0       Assamese     58               11     130           55      137
# 1        Bengali    233               29    1027         1044     1498
# 2           Bodo      4                1       4            1        5
# 3          Dogri      1                0       3            0        1
# 4       Gujarati    811               15    2906          784     1880
# 5          Hindi   8562              141   22768         6628    14265
# 6        Kannada   1117                9    1092         1043     2490
# 7       Kashmiri      3                0       4            0        2
# 8        Konkani      4                0      16            3       39
# 9       Maithili      6                0       2            3       13
# 10     Malayalam    435               18     387          340     2018
# 11      Manipuri     22                0      12            6       21
# ...

# %%
sns.barplot(x=regpublication_df["Daily"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()

# %%
sns.barplot(x=regpublication_df["Bi/Tri-\rWeekly"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()
# Out:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.barplot(x=regpublication_df["Weekly"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()

# %%
sns.barplot(x=regpublication_df["Fortnightly"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()

# %%
sns.barplot(x=regpublication_df["Monthly"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()

# %%
sns.barplot(x=regpublication_df["Quarterly"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()

# %%
sns.barplot(x=regpublication_df["Annual"],y=regpublication_df["Language"],data=regpublication_df)
plt.show()

# %%
regpublication_df.hist(figsize=(15,10))
plt.show()
# Out:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
regpublication_df.describe()
# Out:
#              Daily  Bi/Tri-\rWeekly        Weekly  Fortnightly       Monthly  \
# count    26.000000        26.000000     26.000000    26.000000     26.000000
# mean    768.115385        20.807692   1726.884615   627.192308   1795.000000
# std    1708.913089        33.215682   4490.237912  1309.591204   3127.935434
# min       1.000000         0.000000      2.000000     0.000000      1.000000
# 25%      18.000000         0.250000     16.500000     7.000000     39.000000
# 50%     160.500000        11.000000    388.000000   172.500000    596.000000
# 75%     768.750000        19.500000   1075.750000   770.000000   1983.500000
# max    8562.000000       141.000000  22768.000000  6628.000000  14265.000000
#
#          Quarterly      Annual       Others
# count    26.000000   26.000000    26.000000
# mean    337.000000   93.692308   189.769231
# std     706.028838  190.053839   453.001308
# min       1.000000    0.000000     0.000000
# 25%      12.500000    0.000000     4.250000
# ...

# %%
regpublication_df.corr()
# Out:
#                     Daily  Bi/Tri-\rWeekly    Weekly  Fortnightly   Monthly  \
# Daily            1.000000         0.827232  0.965690     0.964493  0.898650
# Bi/Tri-\rWeekly  0.827232         1.000000  0.806929     0.889148  0.959524
# Weekly           0.965690         0.806929  1.000000     0.960990  0.873622
# Fortnightly      0.964493         0.889148  0.960990     1.000000  0.949384
# Monthly          0.898650         0.959524  0.873622     0.949384  1.000000
# Quarterly        0.606687         0.872618  0.594384     0.701668  0.842477
# Annual           0.176995         0.481617  0.210055     0.263840  0.449254
# Others           0.367101         0.723274  0.331937     0.457101  0.668611
#
#                  Quarterly    Annual    Others
# Daily             0.606687  0.176995  0.367101
# Bi/Tri-\rWeekly   0.872618  0.481617  0.723274
# Weekly            0.594384  0.210055  0.331937
# Fortnightly       0.701668  0.263840  0.457101
# ...
